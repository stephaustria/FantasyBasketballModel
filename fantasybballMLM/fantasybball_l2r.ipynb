# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, ndcg_score

# Set seeds for reproducibility
seed = 42
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Load and preprocess data
data = pd.read_csv('2024_2025_season.csv')  # Replace with actual file name

# Calculate the fantasy score, now scaled by the number of games played (GP)
data['fantasy_score'] = (
    (2 * data['FGM'] - data['FGA'] + data['FTM'] - data['FTA'] +
    data['3P'] + data['PPG'] + 2 * data['APG'] + data['RPG'] +
    4 * (data['STL'] + data['BLK']) - 2 * data['TOV']) * data['GP']
)

# Normalize features
features = ['FGM', 'FGA', 'FTM', 'FTA', '3P', 'PPG', 'APG', 'RPG', 'STL', 'BLK', 'TOV', 'GP']
data[features] = (data[features] - data[features].mean()) / data[features].std()

# Group data for listwise ranking (grouped by 'Team' for example)
grouped_data = data.groupby('Team')
X, y = [], []
for _, group in grouped_data:
    X.append(group[features].values)
    y.append(group['fantasy_score'].values)

# Pad sequences for TensorFlow model
max_group_size = max(len(group) for group in X)
X_padded = tf.keras.preprocessing.sequence.pad_sequences(
    X, maxlen=max_group_size, padding='post', dtype='float32'
)
y_padded = tf.keras.preprocessing.sequence.pad_sequences(
    y, maxlen=max_group_size, padding='post', dtype='float32'
)

# Prepare TensorFlow dataset
def prepare_dataset(X, y):
    dataset = tf.data.Dataset.from_tensor_slices((X, y))
    dataset = dataset.shuffle(buffer_size=100, seed=seed).batch(32)  # Fixed seed for shuffling
    return dataset

train_dataset = prepare_dataset(X_padded, y_padded)

# Define a neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(max_group_size, len(features))),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output relevance score
])

# Custom listwise loss function
def listwise_loss(y_true, y_pred):
    y_pred = tf.nn.softmax(y_pred, axis=1)
    y_true = tf.nn.softmax(y_true, axis=1)
    return -tf.reduce_sum(y_true * tf.math.log(y_pred + 1e-9))

# Compile model with AdamW optimizer
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4),
    loss=listwise_loss,
    metrics=['accuracy']
)

# Train the model
model.fit(train_dataset, epochs=10)

# Predict rankings using the trained model
predictions = model.predict(X_padded)
predictions_flat = [pred[:len(group)] for pred, group in zip(predictions, X)]

# Flatten and align predictions with the dataset
predicted_scores_flat = np.concatenate(predictions_flat).reshape(-1, 1)
true_fantasy_scores = data['fantasy_score'].values.reshape(-1, 1)

# Split data into training and testing for Random Forest
X_train, X_test, y_train, y_test = train_test_split(
    predicted_scores_flat, true_fantasy_scores, test_size=0.2, random_state=seed  # Fixed seed
)

# Hyperparameter tuning for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

rf_regressor = RandomForestRegressor(random_state=seed)
grid_search = GridSearchCV(rf_regressor, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train.ravel())
best_rf = grid_search.best_estimator_

# Use the best model to predict fantasy scores
mapped_fantasy_points = best_rf.predict(predicted_scores_flat)
data['predicted_fantasy_points'] = mapped_fantasy_points

# Evaluate the model
mae = mean_absolute_error(y_test, best_rf.predict(X_test))
ndcg = ndcg_score([y_test.ravel()], [best_rf.predict(X_test)])
print(f"Mean Absolute Error: {mae}")
print(f"NDCG Score: {ndcg}")

# Sort and print all players by predicted fantasy points
ranked_players = data.sort_values(by='predicted_fantasy_points', ascending=False)
all_players = ranked_players[['Name', 'Team', 'Position', 'predicted_fantasy_points']]

print("Full List of Fantasy Basketball Players (Mapped Fantasy Points:")
print(all_players.to_string(index=False))
# Out:
# Epoch 1/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.0000e+00 - loss: 48.0090 - learning_rate: 0.0010
# Epoch 2/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 48.0804 - learning_rate: 0.0010
# Epoch 3/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 47.6962 - learning_rate: 0.0010
# Epoch 4/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 47.8336 - learning_rate: 0.0010
# Epoch 5/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 47.6755 - learning_rate: 0.0010
# Epoch 6/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 47.5185 - learning_rate: 0.0010
# Epoch 7/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 46.9231 - learning_rate: 0.0010
# Epoch 8/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 46.6716 - learning_rate: 0.0010
# Epoch 9/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 46.6649 - learning_rate: 0.0010
# Epoch 10/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 46.5403 - learning_rate: 0.0010
# Epoch 11/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 46.2428 - learning_rate: 0.0010
# Epoch 12/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 45.5228 - learning_rate: 0.0010
# Epoch 13/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 44.9611 - learning_rate: 0.0010
# Epoch 14/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 44.5895 - learning_rate: 0.0010
# Epoch 15/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 44.0055 - learning_rate: 0.0010
# Epoch 16/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 43.5257 - learning_rate: 0.0010
# Epoch 17/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 42.2042 - learning_rate: 0.0010
# Epoch 18/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 41.2215 - learning_rate: 0.0010
# Epoch 19/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 39.7739 - learning_rate: 0.0010
# Epoch 20/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 38.6285 - learning_rate: 0.0010
# Epoch 21/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 37.4371 - learning_rate: 0.0010
# Epoch 22/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 36.1452 - learning_rate: 0.0010
# Epoch 23/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 34.3326 - learning_rate: 0.0010
# Epoch 24/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 32.8809 - learning_rate: 0.0010
# Epoch 25/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 30.7465 - learning_rate: 0.0010
# Epoch 26/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 29.1330 - learning_rate: 0.0010
# Epoch 27/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 27.0561 - learning_rate: 0.0010
# Epoch 28/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 25.4238 - learning_rate: 0.0010
# Epoch 29/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 24.2903 - learning_rate: 0.0010
# Epoch 30/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 23.8602 - learning_rate: 0.0010
# Epoch 31/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 22.1774 - learning_rate: 0.0010
# Epoch 32/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 19.4610 - learning_rate: 0.0010
# Epoch 33/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 18.2117 - learning_rate: 0.0010
# Epoch 34/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 17.6069 - learning_rate: 0.0010
# Epoch 35/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 17.6275 - learning_rate: 0.0010
# Epoch 36/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 17.8151 - learning_rate: 0.0010
# Epoch 37/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 15.6578 - learning_rate: 5.0000e-04
# Epoch 38/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 15.1562 - learning_rate: 5.0000e-04
# Epoch 39/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 17.2154 - learning_rate: 5.0000e-04
# Epoch 40/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 16.7046 - learning_rate: 5.0000e-04
# Epoch 41/82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 16.1988 - learning_rate: 2.5000e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Mean Absolute Error: 608.5290665057463
# NDCG Score: 0.9097705987490565
# Full List of Fantasy Basketball Players (Mapped Fantasy Points):
#                     Name Team   Position  predicted_fantasy_points
#    Giannis Antetokounmpo  MIL      PF, C               3359.679064
#        Victor Wembanyama   SA          C               3305.431621
#        Bogdan Bogdanovic  ATL     SG, SF               3301.206288
#           Damian Lillard  MIL         PG               3216.865637
#            Fred VanVleet  HOU         PG               3211.709433
#  Shai Gilgeous-Alexander  OKC         PG               3189.538922
#           Brandon Miller  CHA     SF, PF               3177.983694
#              Luka Doncic  DAL         PG               3143.118333
#               Jaden Ivey  DET     SG, PG               3138.400748
#              Paul George  PHI     SF, PF               2942.760129
#             Goga Bitadze  ORL          C               2942.760129
# Kentavious Caldwell-Pope  ORL     SG, SF               2942.760129
#             LeBron James  LAL     SF, PF               2942.760129
#               Coby White  CHI     PG, SG               2912.556607
#            Jalen Brunson  NYK         PG               2909.925237
#               Trae Young  ATL         PG               2909.044364
#              LaMelo Ball  CHA         PG               2909.044364
#             Kelly Olynyk  TOR      C, PF               2878.582744
#          Zion Williamson  NOP         PF               2878.582744
#           Paolo Banchero  ORL     PF, SF               2878.582744
#             Desmond Bane  MEM     SG, SF               2870.884588
#              Joel Embiid  PHI          C               2868.624115
#           Darius Garland  CLE         PG               2797.714245
#           Brandon Ingram  NOP         SF               2789.629148
#          Anthony Edwards  MIN     SG, SF               2776.501173
#         Domantas Sabonis  SAC      C, PF               2768.247750
#              CJ McCollum  NOP     SG, PG               2765.618786
#             Kyrie Irving  DAL     PG, SG               2759.886283
#       Benedict Mathurin   IND     SF, SG               2754.434600
#       Karl-Anthony Towns  NYK      C, PF               2754.434600
#        Tyrese Haliburton  IND     PG, SG               2746.661572
#             Jayson Tatum  BOS     PF, SF               2745.503177
#              Jalen Green  HOU         SG               2737.060156
#            Kawhi Leonard  LAC     SF, PF               2732.387469
#            Norman Powell  LAC     SG, SF               2732.387469
#              Josh Giddey  CHI SG, PG, SF               2732.387469
#             John Collins  UTA      PF, C               2732.387469
#             Nikola Jokic  DEN          C               2732.387469
#             Kevin Durant  PHX         PF               2732.387469
#           T.J. McConnell  IND         PG               2707.982102
#            Chet Holmgren  OKC          C               2685.985202
#              Jalen Duren  DET          C               2685.985202
#          Kelly Oubre Jr.  PHI     SF, SG               2659.792098
#              Evan Mobley  CLE       PF,C               2650.528658
#        Jonas Valanciunas  WSH          C               2643.859930
#              Nic Claxton  BKN          C               2641.394004
#            DeMar DeRozan  SAC     SF, PF               2639.463054
#         Donte Divincenzo  MIN         SG               2639.463054
#                Ja Morant  MEM         PG               2636.244769
#            Derrick White  BOS     SG, PG               2633.636436
#           Keyonte George  UTA     PG, SG               2631.349510
#              Alex Caruso  OKC     SG, PG               2628.371479
#            Anthony Davis  LAL      C, PF               2618.683981
#       Kristaps Porzingis  BOS      C, PF               2616.156772
#            Julius Randle  MIN         PF               2604.678705
#             Jamal Murray  DEN         PG               2598.015524
#             Tyrese Maxey  PHI     PG, SG               2589.557620
#        Immanuel Quickley  TOR     PG, SG               2574.468562
#      Dorian Finney-Smith  BKN     PF, SF               2570.988775
#          Stephon Castle    SA     PG, SG               2570.988775
#              Bam Adebayo  MIA          C               2562.258344
#             De'Aaron Fox  SAC         PG               2554.321446
#           Nikola Vucevic  CHI          C               2553.588524
#               Malik Monk  SAC     SG, SF               2549.158230
#            Keegan Murray  SAC     PF, SF               2548.666376
#          Anfernee Simons  POR     SG, PG               2542.154301
#             James Harden  LAC     PG, SG               2502.055042
#        Jaren Jackson Jr.  MEM      C, PF               2493.630176
#            Mikal Bridges  NYK     SF, SG               2492.187285
#           Jalen Williams  OKC  PF, SF, C               2472.969309
#               Cam Thomas  BKN     SG, SF               2472.861662
#               Kyle Kuzma  WSH     PF, SF               2465.565564
#            Jarrett Allen  CLE          C               2463.468889
#          Dennis Schroder  BKN         PG               2455.644609
#             Jerami Grant  POR         PF               2453.579371
#         D'Angelo Russell  LAL     PG, SG               2451.082762
#              Tyler Herro  MIA     SG, PG               2449.582205
#              Deni Avdija  POR     SF, PF               2447.375488
#         Jaime Jaquez Jr.  MIA     SF, SG               2444.019112
#             Terry Rozier  MIA     PG, SG               2440.109764
#          Trey Murphy III  NOP     SF, SG               2437.865956
#             Franz Wagner  ORL     SF, PF               2437.666404
#           Draymond Green  GSW      PC, C               2437.666404
#           Alperen Sengun  HOU          C               2437.293085
#       Isaiah Hartenstein  OKC          C               2437.205801
#          Bilal Coulibaly  WSH     SF, SG               2434.750346
#         Taylor Hendricks  UTA         PF               2434.750346
#              Ivica Zubac  LAC          C               2433.778782
#             Jimmy Butler  MIA SF, SG, PF               2424.489520
#          Dejounte Murray  NOP     SG, PG               2406.696772
#        Russell Westbrook  DEN         PG               2406.319100
#               Chris Paul   SA         PG               2402.148123
#           Alexandre Sarr  WSH          C               2401.371776
#            Jeremy Sochan   SA         PF               2393.770038
#       Michael Porter Jr.  DEN         SF               2388.245650
#            Tobias Harris  DET     PF, SF               2384.071901
#           Cade Cunnigham  DET     PG, SG               2383.429150
#            Stephen Curry  GSW         PG               2383.078299
#             Clint Capela  ATL          C               2370.654455
#             Aaron Gordon  DEN         PF               2369.166384
#           Walker Kessler  UTA          C               2363.063001
#            Rui Hachimura  LAL     PF, SF               2361.004124
#                Kris Dunn  LAC         PG               2361.004124
#            Austin Reaves  LAL     SG, SF               2361.004124
#             Jrue Holiday  BOS     PG, SG               2361.004124
#           Daniel Gafford  DAL          C               2361.004124
#          Cameron Johnson  BKN     SF, PF               2361.004124
#           Andrew Wiggins  GSW     SF, PF               2357.912834
#              Buddy Hield  GSW     SG, SF               2357.912834
#               Tyus Jones  PHX         PG               2357.912834
#             Bradley Beal  PHX     SF, SG               2354.178007
#             Devin Booker  PHX     PG, SG               2352.417069
#           Ausar Thompson  DET     SF, PF               2350.966278
#            Devin Vassell   SA     SG, SF               2332.151229
#                Josh Hart  NYK     SF, SG               2330.276941
#             Bobby Portis  MIL         PF               2327.637252
#            Pascal Siakam  IND         PF               2324.213303
#                 Naz Reid  MIN      C, PF               2319.654368
#              Zach LaVine  CHI     SG, SF               2307.124055
#             Jaylen Brown  BOS     SF, SG               2300.527550
#             Jordan Poole  WSH     SG, PG               2284.981932
#         Donovan Mitchell  CLE     SG, PG               2283.989896
#            Miles Bridges  CHA     SF, PF               2283.989896
#             Caris LeVert  CLE     SG, SF               2281.828856
#            Jalen Johnson  ATL         PF               2279.492292
#              Rudy Gobert  MIN          C               2277.690213
#             Jusuf Nurkic  PHX          C               2276.711305
#            Nick Richards  CHA     SF, PF               2276.711305
#         Jonathan Kuminga  GSW         PF               2252.105472
#      Robert Williams III  POR          C               2251.901449
#          Lauri Markkanen  UTA     PF, SF               2251.901449
#              Brook Lopez  MIL          C               2249.647437
#              Cody Martin  CHA         SG               2244.623802
#          P.J. Washington  DAL         PF               2241.173177
#             Myles Turner  IND          C               2234.012191
#          Khris Middleton  MIL         SF               2217.283646
#             Jared McCain  PHI         SG               2209.626383
#               OG Anunoby  NYK     SF, PF               2207.672494
#         Jabari Smith Jr.  HOU      PF, C               2206.691135
#            Amen Thompson  HOU SF, SG, PF               2198.718811
#              Ayo Dosunmu  CHI         SG               2196.865983
#          Donovan Clingan  POR          C               2194.523190
#           Scottie Barnes  TOR SF, SG, PF               2194.225849
#             Jakob Poeltl  TOR          C               2192.392246
#               RJ Barrett  TOR SF, SG, PF               2112.894298
#         Dereck Lively II  DAL          C               2065.582776
#             Marcus Smart  MEM     SG, PG               2026.346642
#             Santi Aldama  MEM  PF, SF, C               2019.745736
#              Jalen Suggs  ORL     SG, PG               2014.496687
#            Dyson Daniels  ATL     SG, PG               2003.248512
