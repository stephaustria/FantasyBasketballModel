# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, ndcg_score

# Set seeds for reproducibility
seed = 42
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Load and preprocess data
data = pd.read_csv('2024_2025_season.csv')  # Replace with actual file name

# Calculate the fantasy score, now scaled by the number of games played (GP)
data['fantasy_score'] = (
    (2 * data['FGM'] - data['FGA'] + data['FTM'] - data['FTA'] +
    data['3P'] + data['PPG'] + 2 * data['APG'] + data['RPG'] +
    4 * (data['STL'] + data['BLK']) - 2 * data['TOV']) * data['GP']
)

# Normalize features
features = ['FGM', 'FGA', 'FTM', 'FTA', '3P', 'PPG', 'APG', 'RPG', 'STL', 'BLK', 'TOV', 'GP']
data[features] = (data[features] - data[features].mean()) / data[features].std()

# Group data for listwise ranking (grouped by 'Team' for example)
grouped_data = data.groupby('Team')
X, y = [], []
for _, group in grouped_data:
    X.append(group[features].values)
    y.append(group['fantasy_score'].values)

# Pad sequences for TensorFlow model
max_group_size = max(len(group) for group in X)
X_padded = tf.keras.preprocessing.sequence.pad_sequences(
    X, maxlen=max_group_size, padding='post', dtype='float32'
)
y_padded = tf.keras.preprocessing.sequence.pad_sequences(
    y, maxlen=max_group_size, padding='post', dtype='float32'
)

# Prepare TensorFlow dataset
def prepare_dataset(X, y):
    dataset = tf.data.Dataset.from_tensor_slices((X, y))
    dataset = dataset.shuffle(buffer_size=100, seed=seed).batch(32)  # Fixed seed for shuffling
    return dataset

train_dataset = prepare_dataset(X_padded, y_padded)

# Define a neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(max_group_size, len(features))),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output relevance score
])

# Custom listwise loss function
def listwise_loss(y_true, y_pred):
    y_pred = tf.nn.softmax(y_pred, axis=1)
    y_true = tf.nn.softmax(y_true, axis=1)
    return -tf.reduce_sum(y_true * tf.math.log(y_pred + 1e-9))

# Compile model with AdamW optimizer
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4),
    loss=listwise_loss,
    metrics=['accuracy']
)

# Train the model
model.fit(train_dataset, epochs=10)

# Predict rankings using the trained model
predictions = model.predict(X_padded)
predictions_flat = [pred[:len(group)] for pred, group in zip(predictions, X)]

# Flatten and align predictions with the dataset
predicted_scores_flat = np.concatenate(predictions_flat).reshape(-1, 1)
true_fantasy_scores = data['fantasy_score'].values.reshape(-1, 1)

# Split data into training and testing for Random Forest
X_train, X_test, y_train, y_test = train_test_split(
    predicted_scores_flat, true_fantasy_scores, test_size=0.2, random_state=seed  # Fixed seed
)

# Hyperparameter tuning for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

rf_regressor = RandomForestRegressor(random_state=seed)
grid_search = GridSearchCV(rf_regressor, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train.ravel())
best_rf = grid_search.best_estimator_

# Use the best model to predict fantasy scores
mapped_fantasy_points = best_rf.predict(predicted_scores_flat)
data['predicted_fantasy_points'] = mapped_fantasy_points

# Evaluate the model
mae = mean_absolute_error(y_test, best_rf.predict(X_test))
ndcg = ndcg_score([y_test.ravel()], [best_rf.predict(X_test)])
print(f"Mean Absolute Error: {mae}")
print(f"NDCG Score: {ndcg}")

# Sort and print all players by predicted fantasy points
ranked_players = data.sort_values(by='predicted_fantasy_points', ascending=False)
all_players = ranked_players[['Name', 'Team', 'Position', 'predicted_fantasy_points']]

print("Full List of Fantasy Basketball Players (Mapped Fantasy Points:")
print(all_players.to_string(index=False))
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.0000e+00 - loss: 42.1566
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 38.2768
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 34.7442
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 34.5729
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 30.7720
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 28.5084
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 26.8198
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 24.5881
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 24.0531
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 21.1223
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x1747caf20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Mean Absolute Error: 553.32342167307
# NDCG Score: 0.933602367129037
# Full List of Fantasy Basketball Players (Mapped Fantasy Points:
#                     Name Team   Position  predicted_fantasy_points
#        Victor Wembanyama   SA          C               3527.985336
#         Domantas Sabonis  SAC      C, PF               3515.599828
#              Joel Embiid  PHI          C               3141.343499
#             Jayson Tatum  BOS     PF, SF               3140.227415
#             Nikola Jokic  DEN          C               3132.340520
#        Immanuel Quickley  TOR     PG, SG               3010.263939
#    Giannis Antetokounmpo  MIL      PF, C               2994.545690
#  Shai Gilgeous-Alexander  OKC         PG               2979.023529
#             Kevin Durant  PHX         PF               2971.824706
#              Jalen Duren  DET          C               2971.824706
#            Chet Holmgren  OKC          C               2971.824706
#            Kawhi Leonard  LAC     SF, PF               2966.879820
#              LaMelo Ball  CHA         PG               2962.839129
#             Jamal Murray  DEN         PG               2942.212374
#             De'Aaron Fox  SAC         PG               2941.674066
#            Anthony Davis  LAL      C, PF               2906.400884
#              Josh Giddey  CHI SG, PG, SF               2895.890448
#             Jordan Poole  WSH     SG, PG               2890.783406
#              Jalen Green  HOU         SG               2887.316252
#           Jalen Williams  OKC  PF, SF, C               2878.095846
#            Austin Reaves  LAL     SG, SF               2876.936833
#          Anthony Edwards  MIN     SG, SF               2876.936833
#       Karl-Anthony Towns  NYK      C, PF               2866.593519
#               Trae Young  ATL         PG               2817.903227
#           Keyonte George  UTA     PG, SG               2810.138373
#          Donovan Clingan  POR          C               2807.548698
#           Alperen Sengun  HOU          C               2802.506017
#               Kyle Kuzma  WSH     PF, SF               2787.904759
#         Donte Divincenzo  MIN         SG               2780.726163
#            Miles Bridges  CHA     SF, PF               2779.243421
#             James Harden  LAC     PG, SG               2757.174178
#              Nic Claxton  BKN          C               2755.034421
#              Evan Mobley  CLE       PF,C               2718.893011
#              Paul George  PHI     SF, PF               2718.893011
#               Malik Monk  SAC     SG, SF               2718.419999
#              Luka Doncic  DAL         PG               2718.419999
#           Damian Lillard  MIL         PG               2718.419999
#        Tyrese Haliburton  IND     PG, SG               2718.419999
#          Lauri Markkanen  UTA     PF, SF               2718.419999
#            Rui Hachimura  LAL     PF, SF               2718.419999
#           Andrew Wiggins  GSW     SF, PF               2718.419999
#        Jaren Jackson Jr.  MEM      C, PF               2715.805778
# Kentavious Caldwell-Pope  ORL     SG, SF               2711.784994
#            Jalen Brunson  NYK         PG               2706.028799
#             Tyrese Maxey  PHI     PG, SG               2690.404562
#        Russell Westbrook  DEN         PG               2683.806356
#            Devin Vassell   SA     SG, SF               2678.440298
#        Jonas Valanciunas  WSH          C               2676.695847
#           Brandon Miller  CHA     SF, PF               2671.312111
#         Donovan Mitchell  CLE     SG, PG               2669.712029
#             Kyrie Irving  DAL     PG, SG               2668.484690
#            DeMar DeRozan  SAC     SF, PF               2668.484690
#          Trey Murphy III  NOP     SF, SG               2668.238125
#           Cade Cunnigham  DET     PG, SG               2660.478560
#            Fred VanVleet  HOU         PG               2655.061438
#            Julius Randle  MIN         PF               2645.283119
#             Jusuf Nurkic  PHX          C               2640.978781
#                 Naz Reid  MIN      C, PF               2635.089599
#          Stephon Castle    SA     PG, SG               2630.204290
#             Franz Wagner  ORL     SF, PF               2630.204290
#             Myles Turner  IND          C               2625.250906
#             Jimmy Butler  MIA SF, SG, PF               2615.586509
#          Khris Middleton  MIL         SF               2608.310918
#              Bam Adebayo  MIA          C               2607.271215
#           Nikola Vucevic  CHI          C               2604.274077
#            Jalen Johnson  ATL         PF               2600.867577
#          Dejounte Murray  NOP     SG, PG               2576.615301
#               RJ Barrett  TOR SF, SG, PF               2574.683296
#             John Collins  UTA      PF, C               2553.076084
#       Michael Porter Jr.  DEN         SF               2522.709962
#            Derrick White  BOS     SG, PG               2515.738887
#               Coby White  CHI     PG, SG               2514.460913
#           T.J. McConnell  IND         PG               2497.753163
#       Benedict Mathurin   IND     SF, SG               2497.753163
#             Aaron Gordon  DEN         PF               2492.841526
#          Zion Williamson  NOP         PF               2491.273320
#        Bogdan Bogdanovic  ATL     SG, SF               2485.471593
#         Taylor Hendricks  UTA         PF               2467.731793
#           Walker Kessler  UTA          C               2465.301716
#           Darius Garland  CLE         PG               2463.813783
#             Bobby Portis  MIL         PF               2459.708875
#           Paolo Banchero  ORL     PF, SF               2454.915351
#             Caris LeVert  CLE     SG, SF               2452.178867
#            Amen Thompson  HOU SF, SG, PF               2446.194701
#            Mikal Bridges  NYK     SF, SG               2445.926786
#              Zach LaVine  CHI     SG, SF               2444.850933
#             Terry Rozier  MIA     PG, SG               2439.867267
#          Kelly Oubre Jr.  PHI     SF, SG               2438.130098
#             Bradley Beal  PHX     SF, SG               2435.502936
#              Brook Lopez  MIL          C               2435.296824
#            Norman Powell  LAC     SG, SF               2434.773450
#              Tyler Herro  MIA     SG, PG               2433.053287
#             Devin Booker  PHX     PG, SG               2428.430459
#               Cam Thomas  BKN     SG, SF               2428.430459
#               Tyus Jones  PHX         PG               2420.252228
#          Dennis Schroder  BKN         PG               2415.528954
#           Alexandre Sarr  WSH          C               2415.092345
#              CJ McCollum  NOP     SG, PG               2414.534474
#           Scottie Barnes  TOR SF, SG, PF               2410.763198
#             Jakob Poeltl  TOR          C               2406.589793
#           Brandon Ingram  NOP         SF               2404.119462
#                Josh Hart  NYK     SF, SG               2402.376333
#              Ivica Zubac  LAC          C               2394.190748
#         Jaime Jaquez Jr.  MIA     SF, SG               2393.683615
#            Stephen Curry  GSW         PG               2379.106133
#               Jaden Ivey  DET     SG, PG               2365.205536
#             Kelly Olynyk  TOR      C, PF               2365.205536
#            Tobias Harris  DET     PF, SF               2363.746286
#       Kristaps Porzingis  BOS      C, PF               2353.171729
#             LeBron James  LAL     SF, PF               2347.867412
#            Keegan Murray  SAC     PF, SF               2347.867412
#           Daniel Gafford  DAL          C               2343.976194
#      Robert Williams III  POR          C               2330.931724
#          Anfernee Simons  POR     SG, PG               2330.587345
#           Draymond Green  GSW      PC, C               2328.207447
#              Buddy Hield  GSW     SG, SF               2321.501106
#             Jaylen Brown  BOS     SF, SG               2315.014191
#              Deni Avdija  POR     SF, PF               2289.273144
#              Ayo Dosunmu  CHI         SG               2280.799446
#          P.J. Washington  DAL         PF               2272.709414
#            Jeremy Sochan   SA         PF               2266.420819
#             Marcus Smart  MEM     SG, PG               2264.803264
#             Desmond Bane  MEM     SG, SF               2259.955037
#         Jabari Smith Jr.  HOU      PF, C               2252.940913
#             Jrue Holiday  BOS     PG, SG               2222.028633
#               Chris Paul   SA         PG               2214.102920
#         D'Angelo Russell  LAL     PG, SG               2166.754232
#              Cody Martin  CHA         SG               2142.285731
#           Ausar Thompson  DET     SF, PF               2127.831581
#          Bilal Coulibaly  WSH     SF, SG               2109.277164
#            Jarrett Allen  CLE          C               2090.775535
#             Santi Aldama  MEM  PF, SF, C               2088.772607
#              Rudy Gobert  MIN          C               2088.772607
#                Ja Morant  MEM         PG               2080.531823
#             Goga Bitadze  ORL          C               2080.531823
#             Clint Capela  ATL          C               2080.531823
#          Cameron Johnson  BKN     SF, PF               2078.142323
#                Kris Dunn  LAC         PG               2052.630878
#             Jerami Grant  POR         PF               2050.439506
#       Isaiah Hartenstein  OKC          C               2050.439506
#      Dorian Finney-Smith  BKN     PF, SF               2042.951370
#              Alex Caruso  OKC     SG, PG               2042.920495
#               OG Anunoby  NYK     SF, PF               1985.182730
#         Dereck Lively II  DAL          C               1967.270164
#            Pascal Siakam  IND         PF               1742.819229
#         Jonathan Kuminga  GSW         PF               1737.156001
#            Nick Richards  CHA     SF, PF               1726.773004
#            Dyson Daniels  ATL     SG, PG               1688.774426
#             Jared McCain  PHI         SG               1653.262240
#              Jalen Suggs  ORL     SG, PG               1649.285440
