# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import random
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, ndcg_score

# Set seeds for reproducibility
seed = 42
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Load and preprocess data
data = pd.read_csv('2024_2025_season.csv')  # Replace with actual file name

# Calculate the fantasy score, now scaled by the number of games played (GP)
data['fantasy_score'] = (
    (2 * data['FGM'] - data['FGA'] + data['FTM'] - data['FTA'] +
    data['3P'] + data['PPG'] + 2 * data['APG'] + data['RPG'] +
    4 * (data['STL'] + data['BLK']) - 2 * data['TOV']) * data['GP']
)

# Normalize features
features = ['FGM', 'FGA', 'FTM', 'FTA', '3P', 'PPG', 'APG', 'RPG', 'STL', 'BLK', 'TOV', 'GP']
data[features] = (data[features] - data[features].mean()) / data[features].std()

# Group data for listwise ranking (grouped by 'Team' for example)
grouped_data = data.groupby('Team')
X, y = [], []
for _, group in grouped_data:
    X.append(group[features].values)
    y.append(group['fantasy_score'].values)

# Pad sequences for TensorFlow model
max_group_size = max(len(group) for group in X)
X_padded = tf.keras.preprocessing.sequence.pad_sequences(
    X, maxlen=max_group_size, padding='post', dtype='float32'
)
y_padded = tf.keras.preprocessing.sequence.pad_sequences(
    y, maxlen=max_group_size, padding='post', dtype='float32'
)

# Prepare TensorFlow dataset
def prepare_dataset(X, y):
    dataset = tf.data.Dataset.from_tensor_slices((X, y))
    dataset = dataset.shuffle(buffer_size=100, seed=seed).batch(32)  # Fixed seed for shuffling
    return dataset

train_dataset = prepare_dataset(X_padded, y_padded)

# Define a neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(max_group_size, len(features))),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output relevance score
])

# Custom listwise loss function
def listwise_loss(y_true, y_pred):
    y_pred = tf.nn.softmax(y_pred, axis=1)
    y_true = tf.nn.softmax(y_true, axis=1)
    return -tf.reduce_sum(y_true * tf.math.log(y_pred + 1e-9))

# Compile model with AdamW optimizer
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4),
    loss=listwise_loss,
    metrics=['accuracy']
)

# Train the model
model.fit(train_dataset, epochs=10)

# Predict rankings using the trained model
predictions = model.predict(X_padded)
predictions_flat = [pred[:len(group)] for pred, group in zip(predictions, X)]

# Flatten and align predictions with the dataset
predicted_scores_flat = np.concatenate(predictions_flat).reshape(-1, 1)
true_fantasy_scores = data['fantasy_score'].values.reshape(-1, 1)

# Split data into training and testing for Random Forest
X_train, X_test, y_train, y_test = train_test_split(
    predicted_scores_flat, true_fantasy_scores, test_size=0.2, random_state=seed  # Fixed seed
)

# Hyperparameter tuning for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

rf_regressor = RandomForestRegressor(random_state=seed)
grid_search = GridSearchCV(rf_regressor, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train.ravel())
best_rf = grid_search.best_estimator_

# Use the best model to predict fantasy scores
mapped_fantasy_points = best_rf.predict(predicted_scores_flat)
data['predicted_fantasy_points'] = mapped_fantasy_points

# Evaluate the model
mae = mean_absolute_error(y_test, best_rf.predict(X_test))
ndcg = ndcg_score([y_test.ravel()], [best_rf.predict(X_test)])
print(f"Mean Absolute Error: {mae}")
print(f"NDCG Score: {ndcg}")

# Sort and print all players by predicted fantasy points
ranked_players = data.sort_values(by='predicted_fantasy_points', ascending=False)
all_players = ranked_players[['Name', 'Team', 'Position', 'predicted_fantasy_points']]

print("Full List of Fantasy Basketball Players (Mapped Fantasy Points:")
print(all_players.to_string(index=False))
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.3931 - loss: 39.1770
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 34.9035
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 35.6425
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 31.6486
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 30.8758
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 29.2838
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 26.7702
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 24.4059
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 22.5798
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3931 - loss: 22.1409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Mean Absolute Error: 721.5186643212497
# NDCG Score: 0.8505989387059949
# Full List of Fantasy Basketball Players (Mapped Fantasy Points:
#                    Name Team   Position  predicted_fantasy_points
#        Domantas Sabonis  SAC      C, PF               3465.555108
#          Draymond Green  GSW      PC, C               3447.924435
#       Victor Wembanyama   SA          C               3442.119171
#        Donovan Mitchell  CLE     SG, PG               3436.721166
#            Devin Booker  PHX     PG, SG               3367.316645
#       Tyrese Haliburton  IND     PG, SG               3321.325557
#          Walker Kessler  UTA          C               3224.023280
#             Luka Doncic  DAL         PG               3224.023280
#             LaMelo Ball  CHA         PG               3202.948549
#           Julius Randle  MIN         PF               3201.065983
#          Cade Cunnigham  DET     PG, SG               3193.571275
#           Anthony Davis  LAL      C, PF               3178.424925
#           Pascal Siakam  IND         PF               3166.943363
#              Trae Young  ATL         PG               3159.851825
# Shai Gilgeous-Alexander  OKC         PG               3157.293387
#      Michael Porter Jr.  DEN         SF               3151.477387
#             Jalen Suggs  ORL     SG, PG               3112.005135
#   Giannis Antetokounmpo  MIL      PF, C               3112.005135
#            Jakob Poeltl  TOR          C               3112.005135
#              RJ Barrett  TOR SF, SG, PF               3102.995937
#         Dejounte Murray  NOP     SG, PG               3087.266483
#            Kyrie Irving  DAL     PG, SG               3087.193033
#         Zion Williamson  NOP         PF               3079.488020
#            LeBron James  LAL     SF, PF               3079.488020
#             Jalen Green  HOU         SG               3073.209595
#            Kelly Olynyk  TOR      C, PF               3072.879858
#           DeMar DeRozan  SAC     SF, PF               3072.879858
#               Ja Morant  MEM         PG               3055.204460
#            Jayson Tatum  BOS     PF, SF               3046.153698
#             Joel Embiid  PHI          C               3012.798291
#            Myles Turner  IND          C               3006.778909
#             Bam Adebayo  MIA          C               2987.229215
#           Jalen Brunson  NYK         PG               2955.227029
#            Tyrese Maxey  PHI     PG, SG               2947.912937
#              Coby White  CHI     PG, SG               2944.027397
#            Jamal Murray  DEN         PG               2930.854288
#            Desmond Bane  MEM     SG, SF               2913.705112
#            De'Aaron Fox  SAC         PG               2912.727943
#            Franz Wagner  ORL     SF, PF               2902.941749
#          Paolo Banchero  ORL     PF, SF               2887.528742
#            James Harden  LAC     PG, SG               2882.322449
#             Paul George  PHI     SF, PF               2881.856554
#         Anthony Edwards  MIN     SG, SF               2875.238367
#      Kristaps Porzingis  BOS      C, PF               2855.113175
#             Josh Giddey  CHI SG, PG, SF               2855.113175
#           Austin Reaves  LAL     SG, SF               2833.791508
#           Mikal Bridges  NYK     SF, SG               2825.523176
#           Miles Bridges  CHA     SF, PF               2808.273355
#         P.J. Washington  DAL         PF               2806.946103
#           Jarrett Allen  CLE          C               2794.578403
#            Kevin Durant  PHX         PF               2793.249761
#          Scottie Barnes  TOR SF, SG, PF               2775.053070
#           Derrick White  BOS     SG, PG               2771.814267
#            Jaylen Brown  BOS     SF, SG               2758.362036
#         Trey Murphy III  NOP     SF, SG               2712.490292
#            Bradley Beal  PHX     SF, SG               2701.015563
#      Karl-Anthony Towns  NYK      C, PF               2693.225948
#           Fred VanVleet  HOU         PG               2671.771570
#             Brook Lopez  MIL          C               2667.165824
#          Daniel Gafford  DAL          C               2655.531918
#          Damian Lillard  MIL         PG               2653.037100
#         Lauri Markkanen  UTA     PF, SF               2646.024527
#            Jrue Holiday  BOS     PG, SG               2645.680060
#             Nic Claxton  BKN          C               2642.800766
#          Nikola Vucevic  CHI          C               2640.829373
#           Jalen Johnson  ATL         PF               2637.931159
#        D'Angelo Russell  LAL     PG, SG               2634.852284
#          Brandon Miller  CHA     SF, PF               2634.852284
#             Evan Mobley  CLE       PF,C               2594.767437
#            Nikola Jokic  DEN          C               2579.916066
#          Darius Garland  CLE         PG               2568.145495
#       Jaren Jackson Jr.  MEM      C, PF               2559.174676
#            John Collins  UTA      PF, C               2546.657020
#         Cameron Johnson  BKN     SF, PF               2536.773776
#          Jalen Williams  OKC  PF, SF, C               2474.359708
#             Zach LaVine  CHI     SG, SF               2474.359708
#         Dennis Schroder  BKN         PG               2474.359708
#           Stephen Curry  GSW         PG               2440.761214
#             CJ McCollum  NOP     SG, PG               2437.362857
#             Rudy Gobert  MIN          C               2434.395997
#             Tyler Herro  MIA     SG, PG               2424.513918
#            Jordan Poole  WSH     SG, PG               2412.897077
#               Josh Hart  NYK     SF, SG               2409.209131
#      Isaiah Hartenstein  OKC          C               2408.732760
#          Alperen Sengun  HOU          C               2396.397218
#          Alexandre Sarr  WSH          C               2378.516014
#           Dyson Daniels  ATL     SG, PG               2366.672634
#              OG Anunoby  NYK     SF, PF               2358.696636
